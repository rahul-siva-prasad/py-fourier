# %%
from pyFourier import *

# %%
sig1 = f_buildSinWave(freq=2)
sig2 = f_buildCosWave(freq=5)
sig3 = f_buildDcShift(amp =0.25)
sig4 = sig1+sig2+sig3

# %%
sigs = [sig1,sig2,sig3,sig4]

# %%
f_plotGraph(*sigs,title = "Fuck Yeah!")
